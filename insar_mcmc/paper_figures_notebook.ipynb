# %% [markdown]
# # Paper Figures Notebook
#
# This notebook collects the exported main and supplementary figures and points to the table/caption markdown file in `paper_figures`.

# %%
from pathlib import Path
from IPython.display import Image as IPyImage, display, Markdown
ROOT = Path('/home/ubuntu/work/insar_mcmc/paper_figures')
CAPTION_FILE = ROOT / 'FIGURE_TABLE_CAPTIONS.md'
print('Caption/tables file:', CAPTION_FILE)

# %% [markdown]
# ## Main figures

# %%
for name in [
    'figure_1_study_area_dtm_wells.png',
    'figure_2_workflow_schematic.png',
    'figure_3_synthetic_validation.png',
    'figure_4_grouped_stage1_results.png',
    'figure_5_well_validation_map.png',
    'figure_6_best_well_timeseries.png',
]:
    path = ROOT / name
    print(path)
    display(IPyImage(filename=str(path)))

# %% [markdown]
# ## Supplementary figures

# %%
for name in [
    'figure_s1_trusted_aquifer_groups.png',
    'figure_s2_lag_histogram.png',
    'figure_s3_depth_class_summary.png',
    'figure_s4_conditioning_comparison.png',
    'figure_s5_swot_overlap_summary.png',
    'figure_s6_emilia_romagna_wells_overview.png',
]:
    path = ROOT / name
    print(path)
    display(IPyImage(filename=str(path)))

# %% [markdown]
# ## Tables and captions

# %%
display(Markdown(CAPTION_FILE.read_text()))
