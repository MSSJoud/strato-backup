# %% [markdown]
# # EGU Illustrations – Wells, InSAR, Grouped Solution, and Validation
#
# This notebook generates cleaned illustration figures using the validated Bologna products and the selected top-9 wells.

# %%
# %matplotlib inline
from IPython.display import Image, display
from egu_ilus_make_three_illustrations import make_all, OUTDIR
print("Output directory:", OUTDIR)

# %%
paths = make_all()
paths

# %% [markdown]
# ## Illustration 1 – Wells map and cleaned InSAR subarea

# %%
display(Image(filename=str(paths["maps"])))

# %% [markdown]
# ## Illustration 2 – InSAR time series for the selected wells

# %%
display(Image(filename=str(paths["insar_ts"])))

# %% [markdown]
# ## Illustration 3 – Final grouped solution time series at the selected wells

# %%
display(Image(filename=str(paths["grouped"])))

# %% [markdown]
# ## Illustration 4 – Groundwater (Sg) validation against wells

# %%
display(Image(filename=str(paths["validation"])))
