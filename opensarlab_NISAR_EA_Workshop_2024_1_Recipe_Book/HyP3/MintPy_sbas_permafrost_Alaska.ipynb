# %% [markdown]
# # Quantifying Permafrost-Related Ground Feformation with InSAR Time Series Using HyP3 Products and MintPy
#
# ![SAR, InSAR, PolSAR, and banner](https://opensarlab-docs.asf.alaska.edu/opensarlab-notebook-assets/notebook_images/blackboard-banner.png)
#
# The main purpose is to quantifying permafrost-related ground deformation in a local scale.
#
# **Author:** Jie Chen; University of Alaska Fairbanks
#
# Based on the InSAR Time Series Analysis using MintPy and HyP3 products, Alex Lewandowski; University of Alaska Fairbanks.
#
# Based on the [LosAngeles_time_series](https://github.com/ASFOpenSARlab/opensarlab-notebooks/blob/master/SAR_Training/English/Hazards/LosAngeles_time_series.ipynb) notebook by Eric Fielding, David Bekaert, Heresh Fattahi and Yunjun Zhang, which uses an example ARIA dataset.

# %% [markdown]
# # 0: Notebook setup
#
# **Import necessary packages**

# %%
import opensarlab_lib as asfn

import os
import numpy as np
import h5py
import rasterio

from getpass import getpass
from pathlib import Path

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
from mintpy.view import prep_slice, plot_slice

# diff behavior based on mintpy <= 1.4.1 or > 1.4.1
from importlib.metadata import version as getVersion
from packaging import version as compareVersion
mintpy_version = compareVersion.parse(getVersion('mintpy'))
isLatest = mintpy_version > compareVersion.parse('1.4.1')
print(f'The current version of MintPy is: {mintpy_version}')

# MintPy ver beyond 1.4.1
if isLatest:
    from mintpy.cli import view, tsview, plot_network, plot_transection, plot_coherence_matrix
# MintPy <= 1.4.1 (old)
else:
    import mintpy.view as view
    import mintpy.tsview as tsview
    import mintpy.plot_network as plot_network
    import mintpy.plot_transection as plot_transection
    import mintpy.plot_coherence_matrix as plot_coherence_matrix
# Out:
# The current version of MintPy is: 1.5.1

# %% [markdown]
# **Define a project name and create a MintPy directory in which to store files output during our analysis**

# %%
home = Path.home()

# The interferograms acquired from HyP3 are stored in AWS
zip_pth = home/"insar_sbas_permafrost_chen.zip"

work_path = home/"insar_sbas_permafrost_chen"
print(f"Work directory: {work_path}")

# InSAR data path
insar_data = work_path
print(f"InSAR data directory: {insar_data}")

# define a project name (for Sentinel-1 data, the name should start with "Sen_")
proj_name = 'Sen_mintpy_config'
# Out:
# Work directory: /home/jovyan/insar_sbas_permafrost_chen
# InSAR data directory: /home/jovyan/insar_sbas_permafrost_chen

# %% [markdown]
# **Download and unzip the prepared dataset**

# %%
if not work_path.exists():
    # !aws s3 cp --no-sign-request s3://asf-jupyter-data-west/jie_chen/insar_sbas_permafrost_chen.zip {zip_pth}
    # !unzip {zip_pth} -d {home}
    zip_pth.unlink()

# define the MintPy time-series directory
mint_path = work_path/f'MintPy_sbas'
mint_path.mkdir(exist_ok=True)
print(f"MintPy directory: {mint_path}")

#create a directory in which to store plots
plot_path = mint_path/"plots"
plot_path.mkdir(exist_ok=True)
# Out:
# download: s3://asf-jupyter-data-west/jie_chen/insar_sbas_permafrost_chen.zip to ../../insar_sbas_permafrost_chen.zip
# Archive:  /home/jovyan/insar_sbas_permafrost_chen.zip
#    creating: /home/jovyan/insar_sbas_permafrost_chen/
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022/S1AA_20220614T173346_20220720T173348_VVP036_INT80_G_weF_0022_unw_phase_clip.tif.rsc
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA/S1AA_20210619T173340_20220614T173346_VVP360_INT80_G_weF_30FA_dem_clip.tif.rsc
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47/S1AA_20220626T173347_20220708T173347_VVP012_INT80_G_weF_8F47_lv_phi_clip.tif.rsc
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96/S1AA_20210806T173343_20220801T173349_VVP360_INT80_G_weF_7C96_lv_theta_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702/S1AA_20210806T173343_20210911T173345_VVP036_INT80_G_weF_F702_lv_theta_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6/S1AA_20210607T173339_20210701T173341_VVP024_INT80_G_weF_54C6_corr_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2/S1AA_20210725T173342_20210818T173343_VVP024_INT80_G_weF_C8E2_water_mask_clip.tif.rsc
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6/S1AA_20210830T173344_20210911T173345_VVP012_INT80_G_weF_9CA6_lv_phi_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62/S1AA_20210713T173341_20210806T173343_VVP024_INT80_G_weF_EF62_unw_phase_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5/S1AA_20220626T173347_20220801T173349_VVP036_INT80_G_weF_61F5_dem_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/
#    creating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220813_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220614_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210607_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210923_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220930_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210701_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220708_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220918_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220825_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220720_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210830_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210713_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220906_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220602_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210911_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210806_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210725_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210619_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220626_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20220801_18.grb
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/ERA5/ERA5_N60_N70_W170_W160_20210818_18.grb
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20/S1AA_20210619T173340_20210701T173341_VVP012_INT80_G_weF_2A20_wrapped_phase_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2/S1AA_20220602T173345_20220708T173347_VVP036_INT80_G_weF_18B2_amp_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525/S1AA_20220825T173350_20220918T173351_VVP024_INT80_G_weF_E525_dem_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702/S1AA_20220720T173348_20220813T173350_VVP024_INT80_G_weF_2702_lv_theta_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365/S1AA_20210701T173341_20210806T173343_VVP036_INT80_G_weF_8365_unw_phase_clip.tif.rsc
# ...
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_lv_phi_clip.tif.rsc
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE/S1AA_20210818T173343_20210911T173345_VVP024_INT80_G_weF_75BE_corr_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD/S1AA_20210701T173341_20220708T173347_VVP372_INT80_G_weF_05AD_wrapped_phase_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A/S1AA_20210818T173343_20210830T173344_VVP012_INT80_G_weF_8F3A_water_mask_clip.tif
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_lv_phi_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22/S1AA_20210701T173341_20210713T173341_VVP012_INT80_G_weF_1F22_dem_clip.tif.rsc
#    creating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_lv_phi_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_corr_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_unw_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_lv_theta_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_lv_theta_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_amp_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_water_mask_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_corr_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_water_mask_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_unw_phase_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_dem_clip.tif.rsc
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_dem_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8.txt
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_wrapped_phase_clip.tif
#   inflating: /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8/S1AA_20210818T173343_20220825T173350_VVP372_INT80_G_weF_1BF8_lv_phi_clip.tif.rsc
# MintPy directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas

# %% [markdown]
# # 1. Add Your Climate Data Store (CDS) UID & API Key to the Pyaps3 Config
#
# ### This step only needs to be completed once and may be skipped if you have already updated the CDS config
#
# - Running the MintPy smallbaselineApp's `correct_troposphere` step requires downloading atmospheric pressure data from the CDS
# - If don't yet have a CDS API key:
#     - Proceed to [CDS](https://cds.climate.copernicus.eu/cdsapp#!/home) and create an account
#     - Open the [Datasets page](https://cds.climate.copernicus.eu/cdsapp#!/search?type=dataset)
#     - Search for "ERA5"
#     - Select any of ERA5 datasets that appear
#     - Select the `Download data` tab
#     - Scroll to the bottom of the screen
#     - Accept the `Terms of use`
#     - Click on your name at the top right of the screen to access your profile page
#     - Your `UID` and `API Key` will be displayed here
# - Run the following 2 code cells to update the pyaps config from this notebook **OR** open an OpenSARlab terminal and complete the following steps:
#     - Use vim or another text editor to open the `~/.cdsapirc` config file
#         - Add the CDS url to the first line of the config and your CDS `UID` and CDS`API Key` to the 2nd line of the config
#             - This should be formatted like:
#                 - url: https://cds.climate.copernicus.eu/api/v2\
#                 - your_UID: your_API_Key
#         - Save the config and exit the text editor
#
# **If you do not add your CDS credentials to `~/.cdsapirc`, the `correct_troposphere` step will fail**

# %%
pyaps_cfg = Path("/home/jovyan/.cdsapirc")
try:
    with open(pyaps_cfg, 'r') as f:
        lines = f.readlines()
        if len(lines) == 2 and 'url' in lines[0]:
            print("There was a CDS UID and API Key found in the pyaps3 config: ~/.cdsapirc")
            print("Would you like to update them?")
            update_cds_cfg = asfn.select_parameter(["Do not update CDS UID and API Key", 
                                                    "Update CDS UID and API Key"])
            display(update_cds_cfg)
        else:
            update_cds_cfg = None
except FileNotFoundError:
    update_cds_cfg = None
# Out:
# There was a CDS UID and API Key found in the pyaps3 config: ~/.cdsapirc
# Would you like to update them?
# RadioButtons(layout=Layout(min_width='800px'), options=('Do not update CDS UID and API Key', 'Update CDS UID a…

# %%
if not update_cds_cfg or "Update" in update_cds_cfg.value:
    with open(pyaps_cfg, 'w') as f:
            uid = input("Enter your CDS UID")
            key = getpass("Enter your CDS API Key")
            lines = ['', '']
            lines[0] = f"url: https://cds.climate.copernicus.eu/api/v2\n"
            lines[1] = f"key: {uid}:{key}\n"
            f.seek(0)
            f.writelines(lines)
            f.truncate()

# %% [markdown]
# # 2. smallbaselineApp.py overview

# %% [markdown]
# This application provides a workflow which includes several steps to invert a stack of unwrapped interferograms and apply different corrections to obtain ground displacement timeseries.
# The workflow consists of two main blocks:
#
# * correcting unwrapping errors and inverting for the raw phase time-series (blue ovals),
# * correcting for noise from different sources to obtain the displacement time-series (green ovals).
#
# Some steps are optional, which are switched off by default (marked by dashed boundaries). Configuration parameters for each step are initiated with default values in a customizable text file: [smallbaselineApp.cfg](https://github.com/insarlab/MintPy/blob/master/mintpy/defaults/smallbaselineApp.cfg). In this notebook, we will walk through some of these steps, for a complete example see the [MintPy repository](https://github.com/insarlab/MintPy).
#
#
# <p align="left">
#   <img width="600" src="https://opensarlab-docs.asf.alaska.edu/opensarlab-notebook-assets/notebook_images/MintPyWorkflow.jpg">
# </p>
# <p style="text-align: center;">
#     (Figure from Yunjun et al., 2019)
# </p>

# %% [markdown]
# ## 2.1. Processing steps of smallbaselineApp.py

# %% [markdown]
# The MintPy **smallbaselineApp.py** application provides a workflow to invert a stack of unwrapped interferograms and apply different (often optional) corrections to obtain ground displacement timeseries. A detailed overview of the options can be retrieved by involking the help option:

# %% [markdown]
# ## 2.2. Configuring processing parameters

# %% [markdown]
# The processing parameters for the **smallbaselineApp.py** are controlled through a configuration file. If no file is provided the default [smallbaselineApp.cfg](https://github.com/insarlab/MintPy/blob/master/mintpy/defaults/smallbaselineApp.cfg) configuration is used. We will create a custom config file with modified configuration parameters for this time-series analysis. Any options added to the custom config will override options set in the default config.

# %%
# Configure the parameters
insar_processer = 'hyp3'

# Selecting InSAR data
# insar_data_subset = f'{insar_data}/*_{year}????T*_{year}????T*'
insar_data_subset = f'{insar_data}/*'

# Define the start and end date for interferogram pairs
start_date = 'auto'
end_date = 'auto'

network_coh = 0.6

reference_date = '20210607'
ref_latlon = [7529873,522376]

inverse_weight_method = 'var'
inverse_temporal_coh = 0.6
tropospheric_delay_method = 'pyaps'
deramp_method = 'linear'

defo_model_polynomial = 1       # auto for 1, degree of the polynomial function
defo_model_periodic = 1         # auto for no, periods in decimal years
cpu_count = os.cpu_count()

# %%
config = f'''# vim: set filetype=cfg:
##------------------------ smallbaselineApp.cfg ------------------------##
########## computing resource configuration
mintpy.compute.maxMemory = auto #[float > 0.0], auto for 4, max memory to allocate in GB
## parallel processing with dask
## currently apply to steps: invert_network, correct_topography
## cluster   = none to turn off the parallel computing
## numWorker = all  to use all of locally available cores (for cluster = local only)
## numWorker = 80%  to use 80% of locally available cores (for cluster = local only)
## config    = none to rollback to the default name (same as the cluster type; for cluster != local)
mintpy.compute.cluster   = auto #[local / slurm / pbs / lsf / none], auto for none, cluster type
mintpy.compute.numWorker = {cpu_count} #[int > 1 / all / num%], auto for 4 (local) or 40 (slurm / pbs / lsf), num of workers

########## 1. load_data
mintpy.load.processor       = {insar_processer}  #[isce, aria, hyp3, gmtsar, snap, gamma, roipac], auto for isce

##---------interferogram stack:
mintpy.load.unwFile          = {insar_data_subset}/*unw_phase_clip.tif
mintpy.load.corFile          = {insar_data_subset}/*corr_clip.tif

##---------geometry:
mintpy.load.demFile          = {insar_data_subset}/*dem_clip.tif
mintpy.load.incAngleFile     = {insar_data_subset}/*lv_theta_clip.tif
mintpy.load.azAngleFile      = {insar_data_subset}/*lv_phi_clip.tif
mintpy.load.waterMaskFile    = {insar_data_subset}/*water_mask_clip.tif

##---------subset (optional):
## if both yx and lalo are specified, use lalo option unless a) no lookup file AND b) dataset is in radar coord
mintpy.subset.yx            = auto    #[y0:y1,x0:x1 / no], auto for no
mintpy.subset.lalo          = auto    #[S:N,W:E / no], auto for no
# mintpy.subset.lalo          = [7507787:7545857, 495449:548058]    #[S:N,W:E / no], auto for no


########## 2. modify_network
## 1) Network modification based on temporal/perpendicular baselines, date, num of connections etc.
mintpy.network.tempBaseMax     = auto  #[1-inf, no], auto for no, max temporal baseline in days
mintpy.network.perpBaseMax     = auto  #[1-inf, no], auto for no, max perpendicular spatial baseline in meter
mintpy.network.connNumMax      = auto  #[1-inf, no], auto for no, max number of neighbors for each acquisition
mintpy.network.startDate       = {start_date}  #[20090101 / no], auto for no
mintpy.network.endDate         = {end_date}  #[20110101 / no], auto for no
mintpy.network.excludeDate     = auto  #[20080520,20090817 / no], auto for no
mintpy.network.excludeIfgIndex = auto  #[1:5,25 / no], auto for no, list of ifg index (start from 0)

## 2) Data-driven network modification
## a - Coherence-based network modification = (threshold + MST) by default
## reference: Yunjun et al. (2019, section 4.2 and 5.3.1); Chaussard et al. (2015, GRL)
## It calculates a average coherence for each interferogram using spatial coherence based on input mask (with AOI)
## Then it finds a minimum spanning tree (MST) network with inverse of average coherence as weight (keepMinSpanTree)
## Next it excludes interferograms if a) the average coherence < minCoherence AND b) not in the MST network.
mintpy.network.coherenceBased  = yes  #[yes / no], auto for no, exclude interferograms with coherence < minCoherence
mintpy.network.minCoherence    = {network_coh}  #[0.0-1.0], auto for 0.7

## b - Effective Coherence Ratio network modification = (threshold + MST) by default
## reference: Kang et al. (2021, RSE)
## It calculates the area ratio of each interferogram that is above a spatial coherence threshold.
## This threshold is defined as the spatial coherence of the interferograms within the input mask.
## It then finds a minimum spanning tree (MST) network with inverse of the area ratio as weight (keepMinSpanTree)
## Next it excludes interferograms if a) the area ratio < minAreaRatio AND b) not in the MST network.
mintpy.network.areaRatioBased  = no  #[yes / no], auto for no, exclude interferograms with area ratio < minAreaRatio
mintpy.network.minAreaRatio    = 0.8  #[0.0-1.0], auto for 0.75

########## 3. reference_point
## Reference all interferograms to one common point in space
## auto - randomly select a pixel with coherence > minCoherence
## however, manually specify using prior knowledge of the study area is highly recommended
##   with the following guideline (section 4.3 in Yunjun et al., 2019):
## 1) located in a coherence area, to minimize the decorrelation effect.
## 2) not affected by strong atmospheric turbulence, i.e. ionospheric streaks
## 3) close to and with similar elevation as the AOI, to minimize the impact of spatially correlated atmospheric delay
mintpy.reference.yx            = auto   #[257,151 / auto]
mintpy.reference.lalo          = {ref_latlon}   #[31.8,130.8 / auto]

########## 4. correct_unwrap_error (optional)
## connected components (mintpy.load.connCompFile) are required for this step.
## SNAPHU (Chem & Zebker,2001) is currently the only unwrapper that provides connected components as far as we know.
## reference: Yunjun et al. (2019, section 3)
## supported methods:
## a. phase_closure          - suitable for highly redundant network
## b. bridging               - suitable for regions separated by narrow decorrelated features, e.g. rivers, narrow water bodies
## c. bridging+phase_closure - recommended when there is a small percentage of errors left after bridging
mintpy.unwrapError.method          = no  #[bridging / phase_closure / bridging+phase_closure / no], auto for no
mintpy.unwrapError.waterMaskFile   = auto  #[waterMask.h5 / no], auto for waterMask.h5 or no [if not found]
mintpy.unwrapError.connCompMinArea = auto  #[1-inf], auto for 2.5e3, discard regions smaller than the min size in pixels


########## 5. invert_network
## Invert network of interferograms into time-series using weighted least sqaure (WLS) estimator.
## weighting options for least square inversion [fast option available but not best]:
## a. var - use inverse of covariance as weight (Tough et al., 1995; Guarnieri & Tebaldini, 2008) [recommended]
## b. fim - use Fisher Information Matrix as weight (Seymour & Cumming, 1994; Samiei-Esfahany et al., 2016).
## c. coh - use coherence as weight (Perissin & Wang, 2012)
## d. no  - uniform weight (Berardino et al., 2002) [fast]
## SBAS (Berardino et al., 2002) = minNormVelocity (yes) + weightFunc (no)
mintpy.networkInversion.weightFunc      = {inverse_weight_method} #[var / fim / coh / no], auto for var
mintpy.networkInversion.waterMaskFile   = auto #[filename / no], auto for waterMask.h5 or no [if not found]
mintpy.networkInversion.minNormVelocity = auto #[yes / no], auto for yes, min-norm deformation velocity / phase

## mask options for unwrapPhase of each interferogram before inversion (recommend if weightFunct=no):
## a. coherence              - mask out pixels with spatial coherence < maskThreshold
## b. connectComponent       - mask out pixels with False/0 value
## c. no                     - no masking [recommended].
## d. range/azimuthOffsetStd - mask out pixels with offset std. dev. > maskThreshold [for offset]
mintpy.networkInversion.maskDataset   = auto #[coherence / connectComponent / rangeOffsetStd / azimuthOffsetStd / no], auto for no
mintpy.networkInversion.maskThreshold = auto #[0-inf], auto for 0.4
mintpy.networkInversion.minRedundancy = auto #[1-inf], auto for 1.0, min num_ifgram for every SAR acquisition

## Temporal coherence is calculated and used to generate the mask as the reliability measure
## reference: Pepe & Lanari (2006, IEEE-TGRS)
mintpy.networkInversion.minTempCoh  = {inverse_temporal_coh} #[0.0-1.0], auto for 0.7, min temporal coherence for mask
mintpy.networkInversion.minNumPixel = auto #[int > 1], auto for 100, min number of pixels in mask above
mintpy.networkInversion.shadowMask  = auto #[yes / no], auto for yes [if shadowMask is in geometry file] or no.

########## 6. correct_troposphere (optional but recommended)
## correct tropospheric delay using the following methods:
## a. height_correlation - correct stratified tropospheric delay (Doin et al., 2009, J Applied Geop)
## b. pyaps - use Global Atmospheric Models (GAMs) data (Jolivet et al., 2011; 2014)
##      ERA5  - ERA5    from ECMWF [need to install PyAPS from GitHub; recommended and turn ON by default]
##      MERRA - MERRA-2 from NASA  [need to install PyAPS from Caltech/EarthDef]
##      NARR  - NARR    from NOAA  [need to install PyAPS from Caltech/EarthDef; recommended for N America]
## c. gacos - use GACOS with the iterative tropospheric decomposition model (Yu et al., 2018, JGR)
##      need to manually download GACOS products at http://www.gacos.net for all acquisitions before running this step
mintpy.troposphericDelay.method = {tropospheric_delay_method}  #[pyaps / height_correlation / gacos / no], auto for pyaps

## Notes for pyaps:
## a. GAM data latency: with the most recent SAR data, there will be GAM data missing, the correction
##    will be applied to dates with GAM data available and skipped for the others.
## b. WEATHER_DIR: if you define an environment variable named WEATHER_DIR to contain the path to a
##    directory, then MintPy applications will download the GAM files into the indicated directory.
##    MintPy application will look for the GAM files in the directory before downloading a new one to
##    prevent downloading multiple copies if you work with different dataset that cover the same date/time.
mintpy.troposphericDelay.weatherModel = ERA5  #[ERA5 / MERRA / NARR], auto for ERA5
mintpy.troposphericDelay.weatherDir   = auto  #[path2directory], auto for WEATHER_DIR or "./"

########## 7. deramp (optional)
## Estimate and remove a phase ramp for each acquisition based on the reliable pixels.
## Recommended for localized deformation signals, i.e. volcanic deformation, landslide and land subsidence, etc.
## NOT recommended for long spatial wavelength deformation signals, i.e. co-, post- and inter-seimic deformation.
mintpy.deramp          = {deramp_method}  #[no / linear / quadratic], auto for no - no ramp will be removed
mintpy.deramp.maskFile = auto  #[filename / no], auto for maskTempCoh.h5, mask file for ramp estimation


########## 8. correct_topography (optional but recommended)
## Topographic residual (DEM error) correction
## reference: Fattahi and Amelung (2013, IEEE-TGRS)
## stepFuncDate      - specify stepFuncDate option if you know there are sudden displacement jump in your area,
##                     e.g. volcanic eruption, or earthquake
## excludeDate       - dates excluded for the error estimation
## pixelwiseGeometry - use pixel-wise geometry (incidence angle & slant range distance)
##                     yes - use pixel-wise geometry if they are available [slow; used by default]
##                     no  - use the mean   geometry [fast]
mintpy.topographicResidual                   = yes  #[yes / no], auto for yes
mintpy.topographicResidual.polyOrder         = auto  #[1-inf], auto for 2, poly order of temporal deformation model
mintpy.topographicResidual.phaseVelocity     = auto  #[yes / no], auto for no - use phase velocity for minimization
mintpy.topographicResidual.stepFuncDate      = auto  #[20080529,20190704T1733 / no], auto for no, date of step jump
mintpy.topographicResidual.excludeDate       = auto  #[20070321 / txtFile / no], auto for exclude_date.txt
mintpy.topographicResidual.pixelwiseGeometry = auto  #[yes / no], auto for yes, use pixel-wise geometry info


########## 9.1 residual_RMS (root mean squares for noise evaluation)
## Calculate the Root Mean Square (RMS) of residual phase time-series for each acquisition
## reference: Yunjun et al. (2019, section 4.9 and 5.4)
## To get rid of long spatial wavelength component, a ramp is removed for each acquisition
## Set optimal reference date to date with min RMS
## Set exclude dates (outliers) to dates with RMS > cutoff * median RMS (Median Absolute Deviation)
mintpy.residualRMS.maskFile = auto  #[file name / no], auto for maskTempCoh.h5, mask for ramp estimation
mintpy.residualRMS.deramp   = auto  #[quadratic / linear / no], auto for quadratic
mintpy.residualRMS.cutoff   = auto  #[0.0-inf], auto for 3

########## 9.2 reference_date
## Reference all time-series to one date in time
## reference: Yunjun et al. (2019, section 4.9)
## no     - do not change the default reference date (1st date)
mintpy.reference.date = {reference_date}   #[reference_date.txt / 20090214 / no], auto for reference_date.txt


########## 10. velocity
## Estimate a suite of time functions [linear velocity by default]
## from final displacement file (and from tropospheric delay file if exists)
mintpy.timeFunc.startDate   = auto   #[20070101 / no], auto for no
mintpy.timeFunc.endDate     = auto   #[20101230 / no], auto for no
mintpy.timeFunc.excludeDate = auto   #[exclude_date.txt / 20080520,20090817 / no], auto for exclude_date.txt

## Fit a suite of time functions
## reference: Hetland et al. (2012, JGR) equation (2-9)
## polynomial function    is  defined by its degree in integer. 1 for linear, 2 for quadratic, etc.
## periodic   function(s) are defined by a list of periods in decimal years. 1 for annual, 0.5 for semi-annual, etc.
## step       function(s) are defined by a list of onset times in str in YYYYMMDD(THHMM) format
## exp & log  function(s) are defined by an onset time followed by an charateristic time in integer days.
##   Multiple exp and log functions can be overlaied on top of each other, achieved via e.g.:
##   20110311,60,120          - two functions sharing the same onset time OR
##   20110311,60;20170908,120 - separated by ";"
mintpy.timeFunc.polynomial = {defo_model_polynomial}   #[int >= 0], auto for 1, degree of the polynomial function
mintpy.timeFunc.periodic   = {defo_model_periodic}   #[1,0.5 / list_of_float / no], auto for no, periods in decimal years
mintpy.timeFunc.stepDate   = auto   #[20110311,20170908 / 20120928T1733 / no], auto for no, step function(s)
mintpy.timeFunc.exp        = auto   #[20110311,60 / 20110311,60,120 / 20110311,60;20170908,120 / no], auto for no
mintpy.timeFunc.log        = auto   #[20110311,60 / 20110311,60,120 / 20110311,60;20170908,120 / no], auto for no

## Uncertainty quantification methods:
## a. residue    - propagate from fitting residue assuming normal dist. in time (Fattahi & Amelung, 2015, JGR)
## b. covariance - propagate from time series (co)variance matrix
## c. bootstrap  - bootstrapping (independently resampling with replacement; Efron & Tibshirani, 1986, Stat. Sci.)
mintpy.timeFunc.uncertaintyQuantification = auto   #[residue, covariance, bootstrap], auto for residue
mintpy.timeFunc.timeSeriesCovFile         = auto   #[filename / no], auto for no, time series covariance file
mintpy.timeFunc.bootstrapCount            = auto   #[int>1], auto for 400, number of iterations for bootstrapping

mintpy.plot           = no  #[yes / no], auto for yes, plot files generated by default processing to pic folder
'''

# %%
config_path = mint_path/f'{proj_name}.txt'
# updated_config = f'{config}{multithread_config}'
with open(config_path, 'w') as f:
    f.write(config)
    print(f"config file path: {config_path}\n")
# Out:
# config file path: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt

# %% [markdown]
# # 3. Small Baseline Time Series Analysis
#
# **You can run every step in smallbaselineApp.py with one call, using the command in the cell below**
#
# **For the purposes of this tutorial, we will run each step separately**
#
# We will run the steps:
# - load_data
# - modify_network
# - reference_point
# - quick_overview
# - invert_network
# - correct_troposphere
# - correct_topography
# - residual_RMS
# - reference_date
# - velocity
# - google_earth
#
# Skipped steps include:
# - correct_unwrap_error
# - correct_LOD
# - correct_SET
# - deramp
# - hdfeos5
#
# Skipped steps will also be skipped if running the entire smallbaselineApp in the cell below.

# %% [markdown]
# ## 3.1. Load Data
#
# **Run the `load_data` step**
#
# - If you get a missing 'Height' attribute error, you are missing a DEM, which is an available option when ordering HyP3 InSAR products

# %%
# All-in-one step
# !smallbaselineApp.py $config_path --work-dir {mint_path} --start load_data --end velocity

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep load_data
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:50:49.651102--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# copy default template file /home/jovyan/.local/envs/NISAR_EA_Workshop_2024_1/lib/python3.9/site-packages/mintpy/defaults/smallbaselineApp.cfg to work directory
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
#     mintpy.compute.numWorker: auto --> 2
#     mintpy.load.processor: auto --> hyp3
#     mintpy.load.unwFile: auto --> /home/jovyan/insar_sbas_permafrost_chen/*/*unw_phase_clip.tif
#     mintpy.load.corFile: auto --> /home/jovyan/insar_sbas_permafrost_chen/*/*corr_clip.tif
#     mintpy.load.demFile: auto --> /home/jovyan/insar_sbas_permafrost_chen/*/*dem_clip.tif
#     mintpy.load.incAngleFile: auto --> /home/jovyan/insar_sbas_permafrost_chen/*/*lv_theta_clip.tif
#     mintpy.load.azAngleFile: auto --> /home/jovyan/insar_sbas_permafrost_chen/*/*lv_phi_clip.tif
#     mintpy.load.waterMaskFile: auto --> /home/jovyan/insar_sbas_permafrost_chen/*/*water_mask_clip.tif
#     mintpy.network.coherenceBased: auto --> yes
#     mintpy.network.minCoherence: auto --> 0.6
#     mintpy.network.areaRatioBased: auto --> no
#     mintpy.network.minAreaRatio: auto --> 0.8
#     mintpy.reference.lalo: auto --> [7529873, 522376]
#     mintpy.unwrapError.method: auto --> no
#     mintpy.networkInversion.weightFunc: auto --> var
#     mintpy.networkInversion.minTempCoh: auto --> 0.6
#     mintpy.troposphericDelay.method: auto --> pyaps
#     mintpy.troposphericDelay.weatherModel: auto --> ERA5
#     mintpy.deramp: auto --> linear
#     mintpy.topographicResidual: auto --> yes
#     mintpy.reference.date: auto --> 20210607
#     mintpy.timeFunc.polynomial: auto --> 1
#     mintpy.timeFunc.periodic: auto --> 1
#     mintpy.plot: auto --> no
# copy Sen_mintpy_config.txt to inputs   directory for backup.
# copy smallbaselineApp.cfg  to inputs   directory for backup.
# copy Sen_mintpy_config.txt to pic      directory for backup.
# copy smallbaselineApp.cfg  to pic      directory for backup.
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt --project Sen_mintpy_config
# processor : hyp3
# SAR platform/sensor : Sen
# --------------------------------------------------
# prepare metadata files for hyp3 products
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*unw_phase_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*corr_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*dem_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*lv_theta_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*lv_phi_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*water_mask_clip.tif"
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_dem_clip.tif
# incidenceAngle  : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_lv_theta_clip.tif
# azimuthAngle    : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_lv_phi_clip.tif
# waterMask       : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_water_mask_clip.tif
# --------------------------------------------------
# create HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 with w mode
# create dataset /height             of <class 'numpy.float32'>   in size of (125, 125) with compression = lzf
# create dataset /incidenceAngle     of <class 'numpy.float32'>   in size of (125, 125) with compression = lzf
#     convert incidenceAngle  from Gamma (from horizontal in radian)  to MintPy (from vertical in degree) convention.
# create dataset /azimuthAngle       of <class 'numpy.float32'>   in size of (125, 125) with compression = lzf
#     convert azimuthAngle    from Gamma (from east in radian)  to MintPy (from north in degree) convention.
# create dataset /waterMask          of <class 'numpy.bool_'>     in size of (125, 125) with compression = lzf
# prepare slantRangeDistance ...
#     geocoded input, use incidenceAngle from file: S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_lv_theta_clip.tif
#     convert incidence angle from Gamma to MintPy convention.
# create dataset /slantRangeDistance of <class 'numpy.float32'>   in size of (125, 125) with compression = lzf
# Finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5
# --------------------------------------------------
# searching interferogram pairs info
# input data files:
# unwrapPhase     : /home/jovyan/insar_sbas_permafrost_chen/*/*unw_phase_clip.tif
# coherence       : /home/jovyan/insar_sbas_permafrost_chen/*/*corr_clip.tif
# number of unwrapPhase     : 71
# number of coherence       : 71
# --------------------------------------------------
# create HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 with w mode
# create dataset /unwrapPhase of <class 'numpy.float32'>   in size of (71, 125, 125) with compression = None
# [==================================================] 20220918_20220930    0s /     0s
# create dataset /coherence   of <class 'numpy.float32'>   in size of (71, 125, 125) with compression = None
# [==================================================] 20220918_20220930    0s /     0s
# create dataset /date        of <class 'numpy.bytes_'>    in size of (71, 2)
# create dataset /bperp       of <class 'numpy.float32'>   in size of (71,)
# create dataset /dropIfgram  of <class 'numpy.bool_'>     in size of (71,)
# add extra metadata: {'PROJECT_NAME': 'Sen_mintpy_config', 'PLATFORM': 'Sen'}
# Finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# --------------------------------------------------
# searching ionosphere pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['unwrapPhase']! Skip loading for ionosphere stack.
# --------------------------------------------------
# searching offset pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['rangeOffset', 'azimuthOffset']! Skip loading for offset stack.
# time used: 00 mins 1.0 secs.
#
# No lookup table (longitude or rangeCoord) found in files.
# Input data seems to be geocoded. Lookup file not needed.
# Loaded dataset are processed by InSAR software: hyp3
# Loaded dataset are in GEO coordinates
# Interferogram Stack: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# Geometry      File : /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5
# Lookup Table  File : None
# --------------------------------------------------
# updating metadata based on custom template file Sen_mintpy_config.txt for file: ifgramStack.h5
# updating metadata based on custom template file Sen_mintpy_config.txt for file: geometryGeo.h5
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 1.1 secs

# %% [markdown]
# The output of the loading step is an "inputs" directory containing two HDF5 files:
# - ifgramStack.h5: This file contains 6 dataset cubes (e.g. unwrapped phase, coherence, connected components etc.) and multiple metadata.
# - geometryGeo.h5: This file contains geometrical datasets (e.g., incidence/azimuth angle, masks, etc.).

# %%
inputs_path = mint_path/'inputs'
# !ls $inputs_path
# !info.py $inputs_path/ifgramStack.h5
# Out:
# geometryGeo.h5	ifgramStack.h5	Sen_mintpy_config.txt  smallbaselineApp.cfg
# ******************** Basic File Info ************************
# file name: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# file type: ifgramStack
# coordinates : GEO
#
# ******************** HDF5 File Structure ********************
# Attributes in / level:
#   ALOOKS                                          4
#   ANTENNA_SIDE                                    -1
#   AZIMUTH_PIXEL_SIZE                              56.4
#   BANDS                                           1
#   CENTER_LINE_UTC                                 63219.78022
#   DATA_TYPE                                       float32
#   DATE12                                          210607-210619
#   EARTH_RADIUS                                    6360041.1870
#   EPSG                                            32603
#   FILE_LENGTH                                     125
#   FILE_PATH                                       /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_unw_phase_clip.tif
#   FILE_TYPE                                       ifgramStack
#   HEADING                                         -158.0858097
#   HEIGHT                                          706359.2799000004
#   INTERLEAVE                                      BSQ
#   LAT_REF1                                        7535040.0
#   LAT_REF2                                        7535040.0
#   LAT_REF3                                        7525040.0
#   LAT_REF4                                        7525040.0
#   LENGTH                                          125
#   LON_REF1                                        525920.0
#   LON_REF2                                        515920.0
#   LON_REF3                                        525920.0
#   LON_REF4                                        515920.0
#   NO_DATA_VALUE                                   0.0
#   NoDataValue                                     0.0
#   ORBIT_DIRECTION                                 DESCENDING
#   PLATFORM                                        Sen
#   PROCESSOR                                       hyp3
#   PROJECT_NAME                                    Sen_mintpy_config
#   P_BASELINE_BOTTOM_HDR                           -48.0658
#   P_BASELINE_TOP_HDR                              -48.0658
#   RANGE_PIXEL_SIZE                                46.0
#   RLOOKS                                          20
#   STARTING_RANGE                                  804121.9797
#   UTM_ZONE                                        3N
#   WAVELENGTH                                      0.055465764662349676
#   WIDTH                                           125
#   X_FIRST                                         515920.0
#   X_STEP                                          80.0
#   X_UNIT                                          meters
#   Y_FIRST                                         7535040.0
#   Y_STEP                                          -80.0
#   Y_UNIT                                          meters
#   mintpy.compute.cluster                          auto
#   mintpy.compute.maxMemory                        auto
#   mintpy.compute.numWorker                        2
#   mintpy.deramp                                   linear
#   mintpy.deramp.maskFile                          auto
#   mintpy.load.azAngleFile                         /home/jovyan/insar_sbas_permafrost_chen/*/*lv_phi_clip.tif
#   mintpy.load.corFile                             /home/jovyan/insar_sbas_permafrost_chen/*/*corr_clip.tif
#   mintpy.load.demFile                             /home/jovyan/insar_sbas_permafrost_chen/*/*dem_clip.tif
#   mintpy.load.incAngleFile                        /home/jovyan/insar_sbas_permafrost_chen/*/*lv_theta_clip.tif
#   mintpy.load.processor                           hyp3
#   mintpy.load.unwFile                             /home/jovyan/insar_sbas_permafrost_chen/*/*unw_phase_clip.tif
#   mintpy.load.waterMaskFile                       /home/jovyan/insar_sbas_permafrost_chen/*/*water_mask_clip.tif
#   mintpy.network.areaRatioBased                   no
#   mintpy.network.coherenceBased                   yes
#   mintpy.network.connNumMax                       auto
#   mintpy.network.endDate                          auto
#   mintpy.network.excludeDate                      auto
#   mintpy.network.excludeIfgIndex                  auto
#   mintpy.network.minAreaRatio                     0.8
#   mintpy.network.minCoherence                     0.6
#   mintpy.network.perpBaseMax                      auto
#   mintpy.network.startDate                        auto
#   mintpy.network.tempBaseMax                      auto
#   mintpy.networkInversion.maskDataset             auto
#   mintpy.networkInversion.maskThreshold           auto
#   mintpy.networkInversion.minNormVelocity         auto
#   mintpy.networkInversion.minNumPixel             auto
#   mintpy.networkInversion.minRedundancy           auto
#   mintpy.networkInversion.minTempCoh              0.6
#   mintpy.networkInversion.shadowMask              auto
#   mintpy.networkInversion.waterMaskFile           auto
#   mintpy.networkInversion.weightFunc              var
#   mintpy.plot                                     no
#   mintpy.reference.date                           20210607
#   mintpy.reference.lalo                           [7529873, 522376]
#   mintpy.reference.yx                             auto
#   mintpy.residualRMS.cutoff                       auto
#   mintpy.residualRMS.deramp                       auto
#   mintpy.residualRMS.maskFile                     auto
#   mintpy.subset.lalo                              auto
#   mintpy.subset.yx                                auto
#   mintpy.timeFunc.bootstrapCount                  auto
#   mintpy.timeFunc.endDate                         auto
#   mintpy.timeFunc.excludeDate                     auto
#   mintpy.timeFunc.exp                             auto
#   mintpy.timeFunc.log                             auto
#   mintpy.timeFunc.periodic                        1
#   mintpy.timeFunc.polynomial                      1
#   mintpy.timeFunc.startDate                       auto
#   mintpy.timeFunc.stepDate                        auto
#   mintpy.timeFunc.timeSeriesCovFile               auto
#   mintpy.timeFunc.uncertaintyQuantification       auto
#   mintpy.topographicResidual                      yes
#   mintpy.topographicResidual.excludeDate          auto
#   mintpy.topographicResidual.phaseVelocity        auto
#   mintpy.topographicResidual.pixelwiseGeometry    auto
#   mintpy.topographicResidual.polyOrder            auto
#   mintpy.topographicResidual.stepFuncDate         auto
#   mintpy.troposphericDelay.method                 pyaps
#   mintpy.troposphericDelay.weatherDir             auto
#   mintpy.troposphericDelay.weatherModel           ERA5
#   mintpy.unwrapError.connCompMinArea              auto
#   mintpy.unwrapError.method                       no
#   mintpy.unwrapError.waterMaskFile                auto
#
# HDF5 dataset "/bperp               ": shape=(71,)               , dtype=float32   , compression=None
# HDF5 dataset "/coherence           ": shape=(71, 125, 125)      , dtype=float32   , compression=None
#   MODIFICATION_TIME    1705963851.5196166
# HDF5 dataset "/date                ": shape=(71, 2)             , dtype=|S8       , compression=None
# HDF5 dataset "/dropIfgram          ": shape=(71,)               , dtype=bool      , compression=None
# HDF5 dataset "/unwrapPhase         ": shape=(71, 125, 125)      , dtype=float32   , compression=None
#   MODIFICATION_TIME    1705963851.4474156

# %% [markdown]
# <div class="alert alert-info">
# <b>info.py :</b>
# To get general infomation about a MintPy product, run info.py on the file.
# </div>

# %% [markdown]
# ## 3.2. Modify the Network
#
# **Run the `modify_network` step**
#
# - Identifies and excludes interferograms (i.e. affected by remaining coherence phase-unwrapping errors) before the network inversion

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep modify_network
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:50:57.218737--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['modify_network']
# Remaining steps: ['reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - modify_network ********************
# Input data seems to be geocoded. Lookup file not needed.
# generate /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/waterMask.h5 from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 for conveniency
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/waterMask.h5 with w mode
# create dataset /waterMask of bool       in size of (125, 125)           with compression=None
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/waterMask.h5
#
# modify_network.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# No lookup table (longitude or rangeCoord) found in files.
# open ifgramStack file: ifgramStack.h5
# number of interferograms: 71
# --------------------------------------------------
# use coherence-based network modification
# calculating spatial mean of coherence in file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 ...
# read mask from file: waterMask.h5
# [==================================================] 71/71    0s /     0s
# write average value in space into text file: coherenceSpatialAvg.txt
# Get minimum spanning tree (MST) of interferograms with inverse of average coherence.
# Drop ifgrams with 1) average coherence < 0.6 AND 2) not in MST network: (23)
# ['20210607_20220602', '20210607_20220614', '20210619_20210725', '20210619_20220614', '20210619_20220626', '20210701_20210725', '20210701_20210806', '20210701_20220626', '20210701_20220708', '20210713_20220708', '20210713_20220720', '20210725_20220720', '20210725_20220801', '20210806_20220801', '20210806_20220813', '20210818_20220813', '20210818_20220825', '20210830_20210923', '20210830_20220825', '20210923_20220918', '20220614_20220720', '20220626_20220801', '20220708_20220813']
# --------------------------------------------------
# number of interferograms to remove: 23
# number of interferograms to keep  : 48
# open file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 with r+ mode
# update HDF5 dataset "/dropIfgram".
# update MODIFICATION_TIME in HDF5 dataset "/unwrapPhase"
# update MODIFICATION_TIME in HDF5 dataset "/coherence"
# touch coherenceSpatialAvg.txt
# Done.
#
# plot_network.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg --nodisplay -d coherence -v 0.2 1.0
# mintpy.plot is turned OFF, skip plotting network.
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 2.7 secs

# %% [markdown]
# ## 3.3. Plot the interferogram network
#
# Running **plot_network.py** gives an overview of the network and the average coherence of the stack. The program creates multiple files as follows:
# - `ifgramStack_coherence_spatialAvg.txt`: Contains interferogram dates, average coherence temporal and spatial baseline separation.
# - `Network.pdf`: Displays the network of interferograms on time-baseline coordinates, colorcoded by avergae coherence of the interferograms.
# - `CoherenceMatrix.pdf` shows the avergae coherence pairs between all available pairs in the stack.

# %%
# %matplotlib inline
with asfn.work_dir(mint_path):
    plot_network.main((f'{inputs_path}/ifgramStack.h5 -v 0 0.55 --figsize 10 5').split())
    plots = ['bperpHistory.pdf', 'coherenceHistory.pdf', 'coherenceMatrix.pdf', 'network.pdf']
    for p in plots:
        if (mint_path/p).exists():
            (mint_path/p).rename(f'{plot_path}/{p}')
# Out:
# read temporal/spatial baseline info from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# open ifgramStack file: ifgramStack.h5
# ['coherenceSpatialAvg.txt'] exists and is newer than ['/home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5', 'waterMask.h5'] --> skip.
# coherenceSpatialAvg.txt already exists, read it directly
# number of acquisitions: 21
# number of interferograms: 71
# shift all perp baseline by -19.971574783325195 to zero mean for plotting
# --------------------------------------------------
# number of interferograms marked as drop: 23
# number of interferograms marked as keep: 48
# number of acquisitions marked as drop: 0
# max coherence of excluded interferograms: 0.5741
# max perpendicular baseline: 168.40 m
# max temporal      baseline: 372.0 days
# showing coherence
# data range: [0.2921, 0.9633]
# display range: [0.0, 0.55]
# showing ...

# %% [markdown]
# ## 3.4. Set the Reference Point
#
# **Run the `reference_point` step**
#
# The interferometric phase is a relative observation by nature. The phases of each unwrapped interferogram are relative with respect to an arbitrary pixel. Therfore, we need to reference all interferograms to a common reference pixel.
#
# The `reference_point` step selects a common reference pixel for the stack of interferograms. The default approach of MintPy is to choose a pixel with the highest spatial coherence in the stack. Other options include specifying the longitude and latitude of the desired reference pixel or the line and column number of the refence pixel.

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep reference_point
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:51:06.596468--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['reference_point']
# Remaining steps: ['quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - reference_point ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# generate_mask.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 --nonzero -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskConnComp.h5 --update
# input ifgramStack file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskConnComp.h5 NOT exist.
# run or skip: run.
# calculate the common mask of pixels with non-zero unwrapPhase value
# [==================================================] 48/48    0s /     0s
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskConnComp.h5 with w mode
# create dataset /mask of bool       in size of (125, 125)           with compression=None
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskConnComp.h5
# time used: 00 mins 0.0 secs.
#
# temporal_average.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 --dataset coherence -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5 NOT exist.
# run or skip: run.
# calculate the temporal average of coherence in file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 ...
# [==================================================] lines 125/125    0s /     0s
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5 with w mode
# create dataset /coherence of float32    in size of (125, 125)           with compression=None
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5
# time used: 00 mins 0.0 secs
#
# Input data seems to be geocoded. Lookup file not needed.
#
# reference_point.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg -c /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5
# --------------------------------------------------
# reading reference info from template: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# input reference point in lat/lon: (7529873.0, 522376.0)
# input reference point in y/x: (64, 80)
# mask: maskConnComp.h5
# --------------------------------------------------
# calculate the temporal average of unwrapPhase in file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 ...
# [==================================================] lines 125/125    0s /     0s
# Add/update ref_x/y attribute to file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# {'REF_Y': '64', 'REF_X': '80', 'REF_LAT': '7529880.0', 'REF_LON': '522360.0'}
# touch avgSpatialCoh.h5
# touch maskConnComp.h5
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.4 secs

# %% [markdown]
# ## 3.5. Mannually check all the interferograms

# %%
scp_args = f'{inputs_path}/ifgramStack.h5 unwrapPhase-* -v -6 6 --zero-mask --noaxis --noverbose --figsize 10 8'
view.main(scp_args.split() + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 unwrapPhase-* -v -6 6 --zero-mask --noaxis --noverbose --figsize 10 8 --noverbose --nodisplay
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 unwrapPhase-* -v -6 6 --zero-mask --noaxis --noverbose --figsize 10 8

# %% [markdown]
# **Running the "reference_step" adds additional attributes "REF_X, REF_Y" and "REF_LON, REF_LAT" to the `ifgramStack.h5` file. To see the attributes of the file run `info.py`**

# %%
# !info.py $inputs_path/ifgramStack.h5 | egrep 'REF_'
# Out:
#   REF_LAT                                         7529880.0
#   REF_LON                                         522360.0
#   REF_X                                           80
#   REF_Y                                           64

# %% [markdown]
# ## 3.6. Inverting the Small Baseline network
#
# **Run the `invert_network` step**
#
# - Invert the network of differential unwrapped interferograms to estimate the time-series of unwrapped phase with respect to a reference acquisition date
# - By default mintpy selects the first acquisition
# - The estimated time-series is converted to distance change from radar to target and is provided in meters.

# %%
ifgram_path = mint_path/"inputs/ifgramStack.h5"

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep invert_network
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:51:31.243141--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['invert_network']
# Remaining steps: ['correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - invert_network ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# ifgram_inversion.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg --update
# read input option from template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# use dataset "unwrapPhase" by default
# --------------------------------------------------
# update mode: ON
# 1) NOT ALL output files found: ['timeseries.h5', 'temporalCoherence.h5', 'numInvIfgram.h5'].
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# reference pixel in y/x: (64, 80) from dataset: unwrapPhase
# -------------------------------------------------------------------------------
# least-squares solution with L2 min-norm on: deformation velocity
# minimum redundancy: 1.0
# weight function: var
# calculate covariance: False
# mask: no
# -------------------------------------------------------------------------------
# number of interferograms: 48
# number of acquisitions  : 21
# number of lines   : 125
# number of columns : 125
# --------------------------------------------------
# create HDF5 file: timeseries.h5 with w mode
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : bperp      of <class 'numpy.float32'>   in size of (21,)                with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: timeseries.h5
# --------------------------------------------------
# create HDF5 file: temporalCoherence.h5 with w mode
# create dataset  : temporalCoherence of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# close  HDF5 file: temporalCoherence.h5
# --------------------------------------------------
# create HDF5 file: numInvIfgram.h5 with w mode
# create dataset  : mask of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# close  HDF5 file: numInvIfgram.h5
# calculating weight from spatial coherence ...
# reading coherence in (0, 0, 125, 125) * 48 ...
# convert coherence to weight in chunks of 100000 pixels: 1 chunks in total ...
# convert coherence to weight using inverse of phase variance
#     with phase PDF for distributed scatterers from Tough et al. (1995)
#     number of independent looks L=41
# chunk 1 / 1
# reading unwrapPhase in (0, 0, 125, 125) * 48 ...
# use input reference value
# convert zero value in unwrapPhase to NaN (no-data value)
# skip pixels (on the water) with zero value in file: waterMask.h5
# skip pixels with unwrapPhase = NaN in all interferograms
# skip pixels with zero value in file: avgSpatialCoh.h5
# number of pixels to invert: 15624 out of 15625 (100.0%)
# estimating time-series via WLS pixel-by-pixel ...
# [==================================================] 15624/15624 pixels    2s /     0s
# converting LOS phase unit from radian to meter
# --------------------------------------------------
# open  HDF5 file timeseries.h5 in a mode
# writing dataset /timeseries                block: [0, 21, 0, 125, 0, 125]
# close HDF5 file timeseries.h5.
# --------------------------------------------------
# open  HDF5 file temporalCoherence.h5 in a mode
# writing dataset /temporalCoherence         block: [0, 125, 0, 125]
# close HDF5 file temporalCoherence.h5.
# --------------------------------------------------
# open  HDF5 file numInvIfgram.h5 in a mode
# writing dataset /mask                      block: [0, 125, 0, 125]
# close HDF5 file numInvIfgram.h5.
# --------------------------------------------------
# update values on the reference pixel: (64, 80)
# set temporalCoherence on the reference pixel to 1.
# set  # of observations on the reference pixel as 48
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 00 mins 2.8 secs.
#
# Input data seems to be geocoded. Lookup file not needed.
#
# generate_mask.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/temporalCoherence.h5 -m 0.6 -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskTempCoh.h5
# update mode: ON
# run or skip: run
# input temporalCoherence file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/temporalCoherence.h5
# read /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/temporalCoherence.h5
# create initial mask with the same size as the input file and all = 1
# all pixels with nan value = 0
# exclude pixels with value < 0.6
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskTempCoh.h5 with w mode
# create dataset /mask of bool       in size of (125, 125)           with compression=None
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/maskTempCoh.h5
# time used: 00 mins 0.0 secs.
# number of reliable pixels: 15624
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 3.5 secs

# %%
ts_h5 = f'{mint_path}/timeseries.h5'

# %%
# Show the inverted phase history
scp_args = f'{ts_h5} -v -3 3 --noaxis --figsize 10 6'
view.main(scp_args.split() + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5 -v -3 3 --noaxis --figsize 10 6 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5 in float32 format
# file size in y/x: (125, 125)
# num of datasets in file timeseries.h5: 21
# datasets to exclude (0):
# []
# datasets to display (21):
# ['timeseries-20210607', 'timeseries-20210619', 'timeseries-20210701', 'timeseries-20210713', 'timeseries-20210725', 'timeseries-20210806', 'timeseries-20210818', 'timeseries-20210830', 'timeseries-20210911', 'timeseries-20210923', 'timeseries-20220602', 'timeseries-20220614', 'timeseries-20220626', 'timeseries-20220708', 'timeseries-20220720', 'timeseries-20220801', 'timeseries-20220813', 'timeseries-20220825', 'timeseries-20220906', 'timeseries-20220918', 'timeseries-20220930']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries
# figure size : [10.00, 6.00]
# dataset number: 21
# row     number: 4
# column  number: 6
# figure  number: 1
# read mask from file: maskTempCoh.h5
# ----------------------------------------
# Figure 1 - timeseries.png
# reading data as a 3D matrix ...
# data    range: [-2.516821, 2.6937335] cm
# display range: [-3.0, 3.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20220930    0s /     0s
# data    range: [-2.516821, 2.6937335] cm
# display range: [-3.0, 3.0] cm
# show colorbar
# showing ...

# %% [markdown]
# ## 3.7. Correct for Tropospheric Propagation Delays (Optional)
#
# **Run the `correct_troposphere` step**
#
# - Uses ECMWF [ERA5 climate reanalysis pressure data](https://cds.climate.copernicus.eu/cdsapp#!/search?type=dataset&keywords=((%20%22Product%20type:%20Reanalysis%22%20)%20AND%20(%20%22Provider:%20Copernicus%20C3S%22%20))&text=pressure)
# - CDS limits ECMWF archive requests to 50, so your requests may be queued until there is space.
#     - https://cds.climate.copernicus.eu/live/queue

# %%
tropo_choice = asfn.select_parameter(["Perform Tropospheric Correction Step",
                                      "Skip Tropospheric Correction Step",
                                      "Delete Outputs of a Previous (possibly interrupted) Troposheric Correction and Rerun",
                                      "Delete Outputs of a Previous Troposheric Correction and Skip Troposheric Correction Now"])

display(tropo_choice)
# Out:
# RadioButtons(layout=Layout(min_width='800px'), options=('Perform Tropospheric Correction Step', 'Skip Troposph…

# %%
def set_troposhperic_correction_mintpy(config_path, method):
    config_path = Path(config_path)
    with open(config_path, 'r') as f:
        config = f.readlines()    
    config_update = config
    
    for i, l in enumerate(config):
        no_comment = l.split("#")[0]
        present = False
        if "mintpy.troposphericDelay.method=" in "".join(no_comment.split()):
            config_update[i] = f"mintpy.troposphericDelay.method = {method}"
            present = True
            break     
    if not present:
        config_update.append(f"\nmintpy.troposphericDelay.method = {method}")

    config_str = ""
    for l in config_update:
        config_str = f"{config_str}{l}"
    
    with open(config_path, 'w') as f:
        f.write(config_str)

# %%
correct_tropo = "Perform" in tropo_choice.value or "Rerun" in tropo_choice.value
era5_path = mint_path/"ERA5"
timeseries_era5_path = mint_path/"timeseries_ERA5.h5"
inputs_era5_path = mint_path/"inputs/ERA5.h5"

if "Delete" in tropo_choice.value:
    for f in [timeseries_era5_path, inputs_era5_path]:
        try:
            f.unlink()
        except FileNotFoundError:
            pass
    try:
        shutil.rmtree(era5_path)
    except FileNotFoundError:
        pass

if correct_tropo:
    set_troposhperic_correction_mintpy(config_path, "pyaps")
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep load_data
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep correct_troposphere
else:
    set_troposhperic_correction_mintpy(config_path, "no")
    # !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep load_data
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:51:45.396445--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['load_data']
# Remaining steps: ['modify_network', 'reference_point', 'quick_overview', 'correct_unwrap_error', 'invert_network', 'correct_LOD', 'correct_SET', 'correct_troposphere', 'deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# copy Sen_mintpy_config.txt to inputs   directory for backup.
# copy Sen_mintpy_config.txt to pic      directory for backup.
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - load_data ********************
#
# load_data.py --template /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt --project Sen_mintpy_config
# processor : hyp3
# SAR platform/sensor : Sen
# --------------------------------------------------
# prepare metadata files for hyp3 products
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*unw_phase_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*corr_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*dem_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*lv_theta_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*lv_phi_clip.tif"
# prep_hyp3.py "/home/jovyan/insar_sbas_permafrost_chen/*/*water_mask_clip.tif"
# --------------------------------------------------
# updateMode : True
# compression: None
# multilook x/ystep: 1/1
# multilook method : nearest
# --------------------------------------------------
# searching geometry files info
# input data files:
# height          : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_dem_clip.tif
# incidenceAngle  : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_lv_theta_clip.tif
# azimuthAngle    : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_lv_phi_clip.tif
# waterMask       : /home/jovyan/insar_sbas_permafrost_chen/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41/S1AA_20210607T173339_20210619T173340_VVP012_INT80_G_weF_BC41_water_mask_clip.tif
# All datasets exists in file geometryGeo.h5 with same size as required, no need to re-load.
# --------------------------------------------------
# searching interferogram pairs info
# input data files:
# unwrapPhase     : /home/jovyan/insar_sbas_permafrost_chen/*/*unw_phase_clip.tif
# coherence       : /home/jovyan/insar_sbas_permafrost_chen/*/*corr_clip.tif
# number of unwrapPhase     : 71
# number of coherence       : 71
# All date12   exists in file ifgramStack.h5 with same size as required, no need to re-load.
# --------------------------------------------------
# searching ionosphere pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['unwrapPhase']! Skip loading for ionosphere stack.
# --------------------------------------------------
# searching offset pairs info
# input data files:
# WARNING: No data files found for the required dataset: ['rangeOffset', 'azimuthOffset']! Skip loading for offset stack.
# time used: 00 mins 0.8 secs.
#
# No lookup table (longitude or rangeCoord) found in files.
# Input data seems to be geocoded. Lookup file not needed.
# Loaded dataset are processed by InSAR software: hyp3
# Loaded dataset are in GEO coordinates
# Interferogram Stack: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ifgramStack.h5
# Geometry      File : /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5
# Lookup Table  File : None
# --------------------------------------------------
# updating metadata based on custom template file Sen_mintpy_config.txt for file: ifgramStack.h5
# updating metadata based on custom template file Sen_mintpy_config.txt for file: geometryGeo.h5
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 1.0 secs
#
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:51:47.826688--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['correct_troposphere']
# Remaining steps: ['deramp', 'correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - correct_troposphere ********************
# Input data seems to be geocoded. Lookup file not needed.
# Atmospheric correction using Weather Re-analysis dataset (PyAPS, Jolivet et al., 2011)
# Weather Re-analysis dataset: ERA5
#
# tropo_pyaps3.py -f /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5 --model ERA5 -g /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 -w ${WEATHER_DIR}
# weather model: ERA5 - dry (hydrostatic) and wet delay
# weather directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# output tropospheric delay     time-series file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5
# output corrected displacement time-series file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# read dates/time info from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5
# time of cloest available product: 18:00 UTC
#
# --------------------------------------------------------------------------------
# Download global atmospheric model files...
# update mode: ON
# output file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5
# 1) output file either do NOT exist or is NOT newer than all GRIB files.
# run or skip: run
# --------------------------------------------------
# downloading weather model data using PyAPS ...
# common file size: 386280 bytes
# number of grib files existed    : 21
# number of grib files to download: 0
# --------------------------------------------------
#
# --------------------------------------------------------------------------------
# Calculate tropospheric delay and write to HDF5 file...
# update mode: ON
# output file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5
# 1) output file either do NOT exist or is NOT newer than all GRIB files.
# run or skip: run
# open geometry file: geometryGeo.h5
# reading incidenceAngle  data from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 ...
# reading height          data from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 ...
# --------------------------------------------------
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5 with w mode
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : timeseries of <class 'numpy.float32'>   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5
# --------------------------------------------------
# calculating absolute delay for each date using PyAPS (Jolivet et al., 2011; 2014) ...
# number of grib files used: 21
# [==================================================] ERA5_N60_N70_W170_W160_20220930_18.grb   17s /     0s
#
# --------------------------------------------------------------------------------
# Applying tropospheric correction to displacement file...
# correcting relative delay for input time-series using diff.py
# diff.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5 /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5 -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 --force
# /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5 - ['/home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5'] --> /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# the 1st input file is: timeseries
# --------------------------------------------------
# grab metadata from ref_file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5
# grab dataset structure from ref_file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 with w mode
# create dataset  : bperp      of float32                   in size of (21,)                with compression = None
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : timeseries of float32                   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# read from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5
# * referencing data from ERA5.h5 to y/x: 64/80
# * referencing data from ERA5.h5 to date: 20210607
# read from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 in a mode
# writing dataset /timeseries                block: [0, 21, 0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5.
# time used: 00 mins 0.1 secs
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 19.0 secs

# %%
ts_ERA5_h5 = f'{mint_path}/timeseries_ERA5.h5'

# %%
# Display the tropospheric-corrected time series
scp_args = f'{mint_path}/timeseries_ERA5.h5 -v -3 3 --noaxis --figsize 10 6'
view.main(scp_args.split() + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 -v -3 3 --noaxis --figsize 10 6 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 in float32 format
# file size in y/x: (125, 125)
# num of datasets in file timeseries_ERA5.h5: 21
# datasets to exclude (0):
# []
# datasets to display (21):
# ['timeseries-20210607', 'timeseries-20210619', 'timeseries-20210701', 'timeseries-20210713', 'timeseries-20210725', 'timeseries-20210806', 'timeseries-20210818', 'timeseries-20210830', 'timeseries-20210911', 'timeseries-20210923', 'timeseries-20220602', 'timeseries-20220614', 'timeseries-20220626', 'timeseries-20220708', 'timeseries-20220720', 'timeseries-20220801', 'timeseries-20220813', 'timeseries-20220825', 'timeseries-20220906', 'timeseries-20220918', 'timeseries-20220930']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries_ERA5
# figure size : [10.00, 6.00]
# dataset number: 21
# row     number: 4
# column  number: 6
# figure  number: 1
# read mask from file: maskTempCoh.h5
# ----------------------------------------
# Figure 1 - timeseries_ERA5.png
# reading data as a 3D matrix ...
# data    range: [-2.3899822, 2.7206032] cm
# display range: [-3.0, 3.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20220930    0s /     0s
# data    range: [-2.3899822, 2.7206032] cm
# display range: [-3.0, 3.0] cm
# show colorbar
# showing ...

# %% [markdown]
# ## 3.8. Correct for DEM Errors
#
# **Run the `correct_topography` step**

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep deramp
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep correct_topography
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:52:16.261199--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['deramp']
# Remaining steps: ['correct_topography', 'residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - deramp ********************
# Remove for each acquisition a phase ramp: linear
#
# remove_ramp.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 -s linear -m maskTempCoh.h5 -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5 --update
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5 NOT found.
# run or skip: run.
# remove linear ramp from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# grab dataset structure from ref_file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (21,)                with compression = None
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : timeseries of float32                   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 21/21    0s /     0s
# finished writing to file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5
# add/update the following metadata to file:
# add/update mintpy.deramp = linear
# add/update mintpy.deramp.maskFile = maskTempCoh.h5
# time used: 00 mins 0.7 secs.
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.7 secs
#
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:52:18.212518--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['correct_topography']
# Remaining steps: ['residual_RMS', 'reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - correct_topography ********************
# Input data seems to be geocoded. Lookup file not needed.
#
# dem_error.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 --update -g /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5
# read options from template file: smallbaselineApp.cfg
# --------------------------------------------------
# update mode: ON
# 1) output file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 NOT found.
# run or skip: run.
# save the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# set OMP_NUM_THREADS = 1
# set OPENBLAS_NUM_THREADS = 1
# set MKL_NUM_THREADS = 1
# set NUMEXPR_NUM_THREADS = 1
# set VECLIB_MAXIMUM_THREADS = 1
# open timeseries file: timeseries_ERA5_ramp.h5
# --------------------------------------------------------------------------------
# correct topographic phase residual (DEM error) (Fattahi & Amelung, 2013, IEEE-TGRS)
# ordinal least squares (OLS) inversion with L2-norm minimization on: phase
# temporal deformation model: polynomial order = 2
# --------------------------------------------------------------------------------
# add/update the following configuration metadata to file:
# ['polyOrder', 'phaseVelocity', 'stepFuncDate', 'excludeDate']
# --------------------------------------------------
# create HDF5 file: demErr.h5 with w mode
# create dataset  : dem of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# close  HDF5 file: demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 with w mode
# create dataset  : bperp      of float32                   in size of (21,)                with compression = None
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : timeseries of float32                   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5
# --------------------------------------------------
# grab dataset structure from ref_file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseriesResidual.h5 with w mode
# create dataset  : bperp      of float32                   in size of (21,)                with compression = None
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : timeseries of float32                   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseriesResidual.h5
# open geometry file: geometryGeo.h5
# read 2D incidenceAngle, slantRangeDistance from geometry file: geometryGeo.h5
# read mean bperp from timeseries file
# skip pixels with ZERO in ALL acquisitions
# skip pixels with NaN  in ANY acquisitions
# skip pixels with ZERO temporal coherence
# skip pixels with ZERO / NaN value in incidenceAngle / slantRangeDistance
# number of pixels to invert: 15623 out of 15625 (100.0%)
# estimating DEM error pixel-wisely ...
# [==================================================] 15623/15623    1s /     0s
# --------------------------------------------------
# open  HDF5 file demErr.h5 in a mode
# writing dataset /dem                       block: [0, 125, 0, 125]
# close HDF5 file demErr.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in a mode
# writing dataset /timeseries                block: [0, 21, 0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseriesResidual.h5 in a mode
# writing dataset /timeseries                block: [0, 21, 0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseriesResidual.h5.
# roll back to the original settings of ['OMP_NUM_THREADS', 'OPENBLAS_NUM_THREADS', 'MKL_NUM_THREADS', 'NUMEXPR_NUM_THREADS', 'VECLIB_MAXIMUM_THREADS']
# remove env variable OMP_NUM_THREADS
# remove env variable OPENBLAS_NUM_THREADS
# remove env variable MKL_NUM_THREADS
# remove env variable NUMEXPR_NUM_THREADS
# remove env variable VECLIB_MAXIMUM_THREADS
# time used: 00 mins 1.4 secs.
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 1.5 secs

# %%
ts_ERA5_demErr_h5 = f'{mint_path}/timeseries_ERA5_ramp_demErr.h5'

# Calculate the temporal derivative of time-series.
# !temporal_derivative.py $ts_ERA5_demErr_h5
# Out:
# calculating the temporal derivative of timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5
# reading timeseries data
# calculate the 1st derivative of timeseries data
# create timeseries HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr_1stDiff.h5 with w mode
# create dataset /timeseries of float32    in size of (21, 125, 125) with compression=None
# create dataset /dates      of |S8        in size of (21,)
# create dataset /bperp      of float32    in size of (21,)
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr_1stDiff.h5

# %%
# Display the deformation time series
scp_args = f'{ts_ERA5_demErr_h5} -v -3 3 --noaxis --figsize 10 8'
view.main(scp_args.split() + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 -v -3 3 --noaxis --figsize 10 8 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (21):
# ['timeseries-20210607', 'timeseries-20210619', 'timeseries-20210701', 'timeseries-20210713', 'timeseries-20210725', 'timeseries-20210806', 'timeseries-20210818', 'timeseries-20210830', 'timeseries-20210911', 'timeseries-20210923', 'timeseries-20220602', 'timeseries-20220614', 'timeseries-20220626', 'timeseries-20220708', 'timeseries-20220720', 'timeseries-20220801', 'timeseries-20220813', 'timeseries-20220825', 'timeseries-20220906', 'timeseries-20220918', 'timeseries-20220930']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries_ERA5_ramp_demErr
# figure size : [10.00, 8.00]
# dataset number: 21
# row     number: 4
# column  number: 6
# figure  number: 1
# read mask from file: maskTempCoh.h5
# ----------------------------------------
# Figure 1 - timeseries_ERA5_ramp_demErr.png
# reading data as a 3D matrix ...
# data    range: [-2.216077, 2.7560916] cm
# display range: [-3.0, 3.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20220930    0s /     0s
# data    range: [-2.216077, 2.7560916] cm
# display range: [-3.0, 3.0] cm
# show colorbar
# showing ...

# %%
# Display the the temporal derivative of deformation time series
scp_args = f'{mint_path}/timeseries_ERA5_ramp_demErr_1stDiff.h5 -v -3 3 --noaxis --figsize 10 8'
view.main(scp_args.split() + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr_1stDiff.h5 -v -3 3 --noaxis --figsize 10 8 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr_1stDiff.h5 in float32 format
# file size in y/x: (125, 125)
# num of datasets in file timeseries_ERA5_ramp_demErr_1stDiff.h5: 21
# datasets to exclude (0):
# []
# datasets to display (21):
# ['timeseries-20210607', 'timeseries-20210619', 'timeseries-20210701', 'timeseries-20210713', 'timeseries-20210725', 'timeseries-20210806', 'timeseries-20210818', 'timeseries-20210830', 'timeseries-20210911', 'timeseries-20210923', 'timeseries-20220602', 'timeseries-20220614', 'timeseries-20220626', 'timeseries-20220708', 'timeseries-20220720', 'timeseries-20220801', 'timeseries-20220813', 'timeseries-20220825', 'timeseries-20220906', 'timeseries-20220918', 'timeseries-20220930']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries_ERA5_ramp_demErr_1stDiff
# figure size : [10.00, 8.00]
# dataset number: 21
# row     number: 4
# column  number: 6
# figure  number: 1
# read mask from file: maskTempCoh.h5
# ----------------------------------------
# Figure 1 - timeseries_ERA5_ramp_demErr_1stDiff.png
# reading data as a 3D matrix ...
# data    range: [-1.1439489, 3.010902] cm
# display range: [-3.0, 3.0] cm
# masking data
# plotting ...
# [==================================================] timeseries-20220930    0s /     0s
# data    range: [-1.1439489, 3.010902] cm
# display range: [-3.0, 3.0] cm
# show colorbar
# showing ...

# %% [markdown]
# ## 3.9. Calculate the Root Mean Square (RMS) of Residual Phase Time-Series for Each Acquisition
#
# **Run the `residual_RMS` step**
#
# - *reference: Yunjun et al. (2019, section 4.9 and 5.4)*
# - To remove the long wavelength component in space, a phase ramp is removed for each acquisition
# - Sets optimal reference date to date with min RMS
# - Sets exclude dates (outliers) to dates with RMS > cutoff * median RMS (Median Absolute Deviation)

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep residual_RMS
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:52:29.543181--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['residual_RMS']
# Remaining steps: ['reference_date', 'velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - residual_RMS ********************
#
# timeseries_rms.py timeseriesResidual.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read options from template file: smallbaselineApp.cfg
# remove quadratic ramp from file: timeseriesResidual.h5
# read mask file: maskTempCoh.h5
# --------------------------------------------------
# grab metadata from ref_file: timeseriesResidual.h5
# grab dataset structure from ref_file: timeseriesResidual.h5
# create HDF5 file: timeseriesResidual_ramp.h5 with w mode
# create dataset  : bperp      of float32                   in size of (21,)                with compression = None
# create dataset  : date       of |S8                       in size of (21,)                with compression = None
# create dataset  : timeseries of float32                   in size of (21, 125, 125)       with compression = None
# close  HDF5 file: timeseriesResidual_ramp.h5
# estimating phase ramp one date at a time ...
# [==================================================] 21/21    0s /     0s
# finished writing to file: timeseriesResidual_ramp.h5
# time used: 00 mins 0.8 secs.
#
# calculating residual RMS for each epoch from file: timeseriesResidual_ramp.h5
# read mask from file: maskTempCoh.h5
# reading timeseries data from file: timeseriesResidual_ramp.h5 ...
# [==================================================] 21/21    0s /     0s
# save timeseries RMS to text file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/rms_timeseriesResidual_ramp.txt
# read timeseries residual RMS from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/rms_timeseriesResidual_ramp.txt
# --------------------------------------------------
# date with min RMS: 20220801 - 0.0012
# save date to file: reference_date.txt
# --------------------------------------------------
# date(s) with RMS > 3.0 * median RMS (0.0053)
# 20210923 - 0.0056
# save date(s) to file: exclude_date.txt
# save figure to file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/rms_timeseriesResidual_ramp.pdf
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 2.0 secs

# %% [markdown]
# ## 3.10. Reference the Entire Time-Series to One Date in Time
#
# **Run the `reference_date` step**
#
# - *reference: Yunjun et al. (2019, section 4.9)*

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep reference_date
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:52:34.891698--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['reference_date']
# Remaining steps: ['velocity', 'geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - reference_date ********************
#
# reference_date.py -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5 /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5 /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5 /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5
# input reference date: 20210607
# --------------------------------------------------
# change reference date for file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# --------------------------------------------------
# change reference date for file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# --------------------------------------------------
# change reference date for file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# --------------------------------------------------
# change reference date for file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5
# input refDate is the same as the existing REF_DATE.
# Nothing to be done.
# time used: 00 mins 4.0 secs.
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 4.1 secs

# %% [markdown]
# ## 3.11. Estimate The Long-Term Velocity Rate
#
# **Run the `velocity` step**
#
# The timeseries file contains three datasets:
# - the `time-series` dataset, which is the interferometric range change for each acquisition relative to the reference acquisition
# - the `date` dataset, which contains the acquisition date for each acquisition
# - the `bperp` dataset, which contains the timeseries of the perpendicular baseline
#
# The ground deformation caused by many geophysical or anthropogenic processes are linear at first order approximation. Therefore it is common to estimate the rate of the ground deformation which is the slope of linear fit to the time-series.

# %%
# !smallbaselineApp.py $config_path --work-dir {mint_path} --dostep velocity
# Out:
# MintPy version 1.5.1, date 2023-01-03
# --RUN-at-2024-01-22 22:52:42.345781--
# Current directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
# Run routine processing with smallbaselineApp.py on steps: ['velocity']
# Remaining steps: ['geocode', 'google_earth', 'hdfeos5']
# --------------------------------------------------
# Project name: Sen_mintpy_config
# Go to work directory: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas
# read custom template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/Sen_mintpy_config.txt
# update default template based on input custom template
# No new option value found, skip updating /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
# read default template file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg
#
#
# ******************** step - velocity ********************
#
# timeseries2velocity.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 --update
# read options from template file: smallbaselineApp.cfg
# update mode: ON
# 1) output file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 NOT found.
# run or skip: run.
# open timeseries file: timeseries_ERA5_ramp_demErr.h5
# exclude date: ['20210923']
# --------------------------------------------------
# dates from input file: 21
# ['20210607', '20210619', '20210701', '20210713', '20210725', '20210806', '20210818', '20210830', '20210911', '20210923', '20220602', '20220614', '20220626', '20220708', '20220720', '20220801', '20220813', '20220825', '20220906', '20220918', '20220930']
# --------------------------------------------------
# dates used to estimate the time function: 20
# ['20210607', '20210619', '20210701', '20210713', '20210725', '20210806', '20210818', '20210830', '20210911', '20220602', '20220614', '20220626', '20220708', '20220720', '20220801', '20220813', '20220825', '20220906', '20220918', '20220930']
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : [1.0]
#     stepDate   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 with w mode
# create dataset  : intercept       of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : interceptStd    of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : velocity        of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : velocityStd     of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : annualAmplitude of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : annualPhase     of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : residue         of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# add /intercept       attribute: UNIT = m
# add /interceptStd    attribute: UNIT = m
# add /velocity        attribute: UNIT = m/year
# add /velocityStd     attribute: UNIT = m/year
# add /annualAmplitude attribute: UNIT = m
# add /annualPhase     attribute: UNIT = radian
# add /residue         attribute: UNIT = m
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5
# reading data from file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 ...
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 15624 out of 15625 (100.0%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /intercept                 block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /interceptStd              block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /velocity                  block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /velocityStd               block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /annualAmplitude           block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /annualPhase               block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in a mode
# writing dataset /residue                   block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5.
# time used: 00 mins 0.1 secs.
#
# timeseries2velocity.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5 -t /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/smallbaselineApp.cfg -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 --update --ref-date 20210607 --ref-yx 64 80
# read options from template file: smallbaselineApp.cfg
# update mode: ON
# 1) output file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 NOT found.
# run or skip: run.
# open timeseries file: ERA5.h5
# exclude date: ['20210923']
# --------------------------------------------------
# dates from input file: 21
# ['20210607', '20210619', '20210701', '20210713', '20210725', '20210806', '20210818', '20210830', '20210911', '20210923', '20220602', '20220614', '20220626', '20220708', '20220720', '20220801', '20220813', '20220825', '20220906', '20220918', '20220930']
# --------------------------------------------------
# dates used to estimate the time function: 20
# ['20210607', '20210619', '20210701', '20210713', '20210725', '20210806', '20210818', '20210830', '20210911', '20220602', '20220614', '20220626', '20220708', '20220720', '20220801', '20220813', '20220825', '20220906', '20220918', '20220930']
# --------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : [1.0]
#     stepDate   : []
#     exp        : {}
#     log        : {}
# add/update the following configuration metadata:
# ['startDate', 'endDate', 'excludeDate', 'polynomial', 'periodic', 'stepDate', 'exp', 'log', 'uncertaintyQuantification', 'timeSeriesCovFile', 'bootstrapCount']
# --------------------------------------------------
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 with w mode
# create dataset  : intercept       of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : interceptStd    of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : velocity        of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : velocityStd     of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : annualAmplitude of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : annualPhase     of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# create dataset  : residue         of <class 'numpy.float32'>   in size of (125, 125)           with compression = None
# add /intercept       attribute: UNIT = m
# add /interceptStd    attribute: UNIT = m
# add /velocity        attribute: UNIT = m/year
# add /velocityStd     attribute: UNIT = m/year
# add /annualAmplitude attribute: UNIT = m
# add /annualPhase     attribute: UNIT = radian
# add /residue         attribute: UNIT = m
# close  HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5
# reading data from file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/ERA5.h5 ...
# referecing to date: 20210607
# referencing to point (y, x): (64, 80)
# skip pixels with zero/nan value in all acquisitions
# number of pixels to invert: 15625 out of 15625 (100.0%)
# estimating time functions via linalg.lstsq ...
# estimating time functions STD from time-series fitting residual ...
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /intercept                 block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /interceptStd              block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /velocity                  block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /velocityStd               block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /annualAmplitude           block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /annualPhase               block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# --------------------------------------------------
# open  HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5 in a mode
# writing dataset /residue                   block: [0, 125, 0, 125]
# close HDF5 file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocityERA5.h5.
# time used: 00 mins 0.1 secs.
# Go back to directory: /home/jovyan/opensarlab_NISAR_EA_Workshop_2024_1_Recipe_Book/HyP3
#
# ################################################
#    Normal end of smallbaselineApp processing!
# ################################################
# Time used: 00 mins 0.2 secs

# %%
# Calculate the amplitude of seasonal deformation which is double of the annual amplitude.
# !image_math.py $mint_path/velocity.h5 '*' 2 --output $mint_path/season.h5
# Out:
# input is hyp3 velocity file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5
# operation: file * 2.000000
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/season.h5 with w mode
# create dataset /velocity        of float32    in size of (125, 125)           with compression=None
# create dataset /annualAmplitude of float32    in size of (125, 125)           with compression=None
# create dataset /annualPhase     of float32    in size of (125, 125)           with compression=None
# create dataset /velocityStd     of float32    in size of (125, 125)           with compression=None
# create dataset /intercept       of float32    in size of (125, 125)           with compression=None
# create dataset /interceptStd    of float32    in size of (125, 125)           with compression=None
# create dataset /residue         of float32    in size of (125, 125)           with compression=None
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/season.h5

# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 12})
# from cartopy import crs as ccrs
from mintpy.view import prep_slice, plot_slice

# view.py options
opt = f'--dem {inputs_path}/geometryGeo.h5 --shade-exag 0.05 --dem-nocontour --ylabel-rot 90 --noverbose --noscalebar '
cmd_list = [
    f'view.py {mint_path}/velocity.h5 velocity {opt} -v -3 3',
    f'view.py {mint_path}/season.h5 annualAmplitude {opt} -v -5 5',
    # f'view.py {mint_path}/velocityRaw.h5 annualPhase {opt} -c cmy -v 0 3.14',
]

# plot using matplotlib & mintpy.view
fig, axs = plt.subplots(nrows=2, ncols=1, figsize=[30, 20])
for ax, cmd in zip(axs.flatten(), cmd_list):
    data, atr, inps = prep_slice(cmd)
    plot_slice(ax, data, atr, inps)
plt.show()
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 velocity --dem /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 --shade-exag 0.05 --dem-nocontour --ylabel-rot 90 --noverbose --noscalebar -v -3 3
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/season.h5 annualAmplitude --dem /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 --shade-exag 0.05 --dem-nocontour --ylabel-rot 90 --noverbose --noscalebar -v -5 5

# %% [markdown]
# ## 3.12. Plot the Cumulative Displacement Map and Point Displacement Time Series
#
# - Use the `Time` bar below the Cumulative Displacement Map to view displacements for different time periods
# - Click on the Cumulative Displacement Map to select points for displaying Point Displacement Time-Series

# %%
demErr = 'timeseries_ERA5_ramp_demErr.h5' if correct_tropo else 'timeseries_ramp_demErr.h5'
ts_demErr = mint_path/f'{demErr}'
temp_coh_msk_h5 = mint_path/'maskTempCoh.h5'

# %%
# %matplotlib widget
scp_args = f'{ts_demErr} -d {mint_path}/inputs/geometryGeo.h5 --poly 1 --periodic 1.0 --ylim -4 4 --figsize 10 7 -o {mint_path}/displacement_ts --outfile {mint_path}/displacement_ts.pdf'
print(scp_args)
tsview.main(scp_args.split())
# Out:
# /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 -d /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 --poly 1 --periodic 1.0 --ylim -4 4 --figsize 10 7 -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/displacement_ts --outfile /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/displacement_ts.pdf
# tsview.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 -d /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/inputs/geometryGeo.h5 --poly 1 --periodic 1.0 --ylim -4 4 --figsize 10 7 -o /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/displacement_ts --outfile /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/displacement_ts.pdf
# open timeseries file: timeseries_ERA5_ramp_demErr.h5
# No lookup table (longitude or rangeCoord) found in files.
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# estimate deformation model with the following assumed time functions:
#     polynomial : 1
#     periodic   : [1.0]
#     stepDate   : []
#     exp        : {}
#     log        : {}
# reading timeseries from file /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5
# reference to date: 20210607
# read mask from file: maskTempCoh.h5
# data    range: [-2.216077, 2.7560916] cm
# display range: [-1.4229726, 1.5500454] cm
# create figure for map in size of [6.5, 6.0]
# reading DEM: geometryGeo.h5 ...
# display data in transparency: 0.7
# plot in geo-coordinate
# plotting DEM background ...
# show shaded relief DEM (min/max=-4000/2225 m; exag=0.5; az/alt=315.0/45.0 deg)
# WARNING: elevation range (9.4-225.1 m) < 2 contour levels (400.0 m) --> skip plotting DEM contour and continue
# plotting image ...
# plot scale bar: [0.2, 0.2, 0.1]
# plot reference point
# create figure for point in size of [10.0, 7.0]
# showing ...
#
# ------------------------------------------------------------------------
# To scroll through the image sequence:
# 1) Move the slider, OR
# 2) Press left or right arrow key (if not responding, click the image and try again).
# ------------------------------------------------------------------------
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <div class="alert alert-info">
# <b>Note :</b>
# Negative values indicates that target is moving away from the radar (i.e., Subsidence in case of vertical deformation).
# Positive values indicates that target is moving towards the radar (i.e., uplift in case of vertical deformation).
# </div>

# %% [markdown]
# # 4. Error analysis (signal vs noise)
#
# Uncertainty of the ground displacement products derived from InSAR time-series, depends on the quality of the inversion of the stack of interferograms and the accuracy in separating the ground displacement from other components of the InSAR data. Therefore the definition of signal vs noise is different at the two main steps in MintPy:
#
# 1) During the inversion:
#     At this step all systematic components of the interferometric phase (e.g., ground displacement, propagation delay, geometrical residuals caused by DEM or platform's orbit inaccuracy) are considered signal, while the interferometric phase decorrelation, phase unwrapping error and phase inconsistency are considered noise.
#
# 2) After inversion: the ground displacement component of the time-serieses is signal, and everything else (including the propagation delay and geometrical residuals) are considered noise
#
# Therefore we first discuss the possible sources of error during the inversion and the existing ways in MintPy to evaluate the quality of inversion and to improve the uncertainty of the inversion. Afterwards we explain the different components of the time-series and the different processing steps in MintPy to separate them from ground displacement signal.

# %% [markdown]
# ## 4.1. Quality of the inversion
#
# The main sources of noise during the time-series inversion includes decorrelation, phase unwrapping error and the inconsistency of triplets of interferofgrams. Here we mainly focus on the decorrelation and unwrapping errors. We first show the existing quantities in MintPy to evaluate decorrelation and unwrapping errors and then discuss the existing ways in MintPy to reduce the decorrelation and unwrapping errors on the time-series inversion.
#
# ### 4.1.1. Average spatial coherence
#
# Mintpy computes temporal average of spatial coherence of the entire stack as a potential ancillary measure to choose reliable pixels after time-series inversion.

# %%
scp_args = f"{mint_path}/avgSpatialCoh.h5 --dpi 600 --figsize 12 12 --outfile {plot_path}/avg_spatial_coh.png"
view.main(scp_args.split()[:-2] + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5 --dpi 600 --figsize 12 12 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is coherence file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5 in float32 format
# file size in y/x: (125, 125)
# num of datasets in file avgSpatialCoh.h5: 1
# datasets to exclude (0):
# []
# datasets to display (1):
# ['coherence']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: gray
# figure title: avgSpatialCoh
# reading data ...
# masking pixels with NO_DATA_VALUE of 0.0
# data    range: [0.38290286, 0.9683592] 1
# display range: [0.0, 1.0] 1
# display data in transparency: 1.0
# plot in geo-coordinate
# plotting image ...
# plot scale bar: [0.2, 0.2, 0.1]
# save figure to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/plots/avg_spatial_coh.png with dpi=600
# showing ...

# %% [markdown]
# ### 4.1.2. Temporal coherence
#
# In addition to timeseries.h5 which contains the time-series dataset, invert_network produces other quantities, which contain metrics to evaluate the quality of the inversion including temporalCoherence.h5. Temporal coherence represents the consistency of the timeseries with the network of interferograms.
#
# Temporal coherence varies from 0 to 1. Pixels with values closer to 1 are considered reliable and pixels with values closer to zero are considered unreliable. For a dense network of interferograms, a threshold of 0.7 may be used (Yunjun et al, 2019).

# %%
scp_args = f"{mint_path}/temporalCoherence.h5 -v 0.6 1 --dpi 600 --figsize 8 8 --outfile {plot_path}/temporal_coh.png"
view.main(scp_args.split()[:-2] + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/temporalCoherence.h5 -v 0.6 1 --dpi 600 --figsize 8 8 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is temporalCoherence file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/temporalCoherence.h5 in float32 format
# file size in y/x: (125, 125)
# num of datasets in file temporalCoherence.h5: 1
# datasets to exclude (0):
# []
# datasets to display (1):
# ['temporalCoherence']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: gray
# figure title: temporalCoherence
# reading data ...
# masking pixels with NO_DATA_VALUE of 0.0
# data    range: [0.79279655, 1.0] 1
# display range: [0.6, 1.0] 1
# display data in transparency: 1.0
# plot in geo-coordinate
# plotting image ...
# plot scale bar: [0.2, 0.2, 0.1]
# plot reference point
# save figure to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/plots/temporal_coh.png with dpi=600
# showing ...

# %% [markdown]
# ## 4.2. Velocity error analysis
#
# The estimated velocity also comes with an expression of unecrtainty which is simply based on the goodness of fit while fitting a linear model to the time-series. This quantity is saved in "velocity.h5" under the velocityStd dataset.

# %%
scp_args = f'{mint_path}/velocity.h5 velocityStd -v 0 0.2 --dpi 600 --figsize 12 12 --outfile {plot_path}/velocity_err.png'
# scp_args = f'{mint_path}/velocity.h5 interceptStd -v 0 0.5 --dpi 600 --figsize 12 12 --outfile {plot_path}/season_err.png'
view.main(scp_args.split()[:-2] + ['--noverbose', '--nodisplay'])
# %matplotlib inline
view.main(scp_args.split())
# Out:
# view.py /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 velocityStd -v 0 0.2 --dpi 600 --figsize 12 12 --noverbose --nodisplay
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is velocity file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['velocityStd']"
# turning glob search OFF for velocity file
# num of datasets in file velocity.h5: 7
# datasets to exclude (0):
# []
# datasets to display (1):
# ['velocityStd']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: velocityStd
# read mask from file: maskTempCoh.h5
# reading data ...
# masking data
# masking pixels with NO_DATA_VALUE of 0.0
# data    range: [0.0066681895, 0.23223245] cm/year
# display range: [0.0, 0.2] cm/year
# display data in transparency: 1.0
# plot in geo-coordinate
# plotting image ...
# plot scale bar: [0.2, 0.2, 0.1]
# plot reference point
# save figure to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/plots/velocity_err.png with dpi=600
# showing ...

# %% [markdown]
# Note that the plot above is the velocity error, not the velocity. The errors generally increases with distance from the reference point and can also increase for points with elevations different from the reference point if topographically correlated water vapor variations are especially strong in the area.

# %% [markdown]
# # 5. Generate products of coherence, velocity, and total displacement Geotiffs

# %% [markdown]
# **Create directories in which to store output we will create in upcoming steps**

# %%
geotiff_path = mint_path/'GeoTiffs'
geotiff_path.mkdir(exist_ok=True)

disp_path = geotiff_path/'displacement_maps'
disp_path.mkdir(exist_ok=True)

# %%
with h5py.File(ts_demErr, "r") as f:
    dates = f["date"][()]
    date_list = [str(int(d)) for d in dates]
date_list
with h5py.File(ts_demErr, 'r') as f:
    unw_path = f.attrs['FILE_PATH']
ds_unw = rasterio.open(unw_path, 'r', driver='GTiff')

for i, d in enumerate(date_list):
    cmd = f'view.py {ts_demErr} {date_list[i]} --notitle --notick --noaxis'
    data, _, _ = prep_slice(cmd)
    data = data / 100 # cm -> meters
        
    with rasterio.open(f'{disp_path}/defo_{date_list[i]}.tif', 'w', driver='GTiff',
                  height = data.shape[0], width = data.shape[1],
                  count=1, dtype=str(data.dtype),
                  crs=ds_unw.read_crs(),
                  transform=ds_unw.transform,
                  nodata=np.nan) as ds:
        ds.write(data.astype(rasterio.float32), 1)
# Out:
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210607']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210607']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210607_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [0.0, 0.0] cm
# display range: [0.0, 0.0] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210619']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210619']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210619_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-0.619755, 1.1491957] cm
# display range: [-0.619755, 1.1491957] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210701']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210701']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210701_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-0.96906054, 1.6694216] cm
# display range: [-0.96906054, 1.6694216] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210713']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210713']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210713_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.1038487, 1.3565772] cm
# display range: [-1.1038487, 1.3565772] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210725']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210725']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210725_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.7060448, 0.99462134] cm
# display range: [-1.7060448, 0.99462134] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210806']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210806']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210806_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-2.0694606, 0.93804646] cm
# display range: [-2.0694606, 0.93804646] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210818']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210818']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210818_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.7578919, 1.0921003] cm
# display range: [-1.7578919, 1.0921003] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210830']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210830']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210830_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.4914808, 1.2383447] cm
# display range: [-1.4914808, 1.2383447] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210911']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210911']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210911_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.6949186, 1.0482994] cm
# display range: [-1.6949186, 1.0482994] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20210923']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20210923']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20210923_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-2.023251, 1.2312214] cm
# display range: [-2.023251, 1.2312214] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220602']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220602']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220602_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.6052796, 2.6531062] cm
# display range: [-1.6052796, 2.6531062] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220614']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220614']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220614_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.3469734, 2.7560916] cm
# display range: [-1.3469734, 2.7560916] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220626']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220626']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220626_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.4170209, 2.593122] cm
# display range: [-1.4170209, 2.593122] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220708']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220708']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220708_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.4734259, 2.1874423] cm
# display range: [-1.4734259, 2.1874423] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220720']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220720']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220720_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.5223252, 1.6123347] cm
# display range: [-1.5223252, 1.6123347] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220801']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220801']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220801_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.7235004, 1.5945603] cm
# display range: [-1.7235004, 1.5945603] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220813']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220813']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220813_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.6320603, 1.8352051] cm
# display range: [-1.6320603, 1.8352051] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220825']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220825']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220825_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-2.216077, 1.4183779] cm
# display range: [-2.216077, 1.4183779] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220906']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220906']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220906_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.9026924, 1.4359306] cm
# display range: [-1.9026924, 1.4359306] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220918']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220918']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220918_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.9064367, 1.3317116] cm
# display range: [-1.9064367, 1.3317116] cm
# run view.py in MintPy version 1.5.1, date 2023-01-03
# input file is timeseries file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/timeseries_ERA5_ramp_demErr.h5 in float32 format
# file size in y/x: (125, 125)
# input dataset: "['20220930']"
# num of datasets in file timeseries_ERA5_ramp_demErr.h5: 21
# datasets to exclude (0):
# []
# datasets to display (1):
# ['timeseries-20220930']
# data   coverage in y/x: (0, 0, 125, 125)
# subset coverage in y/x: (0, 0, 125, 125)
# data   coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# subset coverage in lat/lon: (515920.0, 7535040.0, 525920.0, 7525040.0)
# ------------------------------------------------------------------------
# colormap: jet
# figure title: timeseries-20220930_ERA5_ramp_demErr
# figure size : [7.50, 6.00]
# read mask from file: maskTempCoh.h5
# data    range: [-1.7887207, 1.7128559] cm
# display range: [-1.7887207, 1.7128559] cm

# %% [markdown]
# **Save the average spatial coherence and temporal coherence geotiff**

# %%
# !save_gdal.py $mint_path/avgSpatialCoh.h5 --of GTIFF -o $geotiff_path/avgSpatialCoh.tif
# !save_gdal.py $mint_path/temporalCoherence.h5 --of GTIFF -o $geotiff_path/TemporalCoherence.tif
# Out:
# read data from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/avgSpatialCoh.h5
# initiate GDAL driver: GeoTIFF
# create raster band
# raster row / column number: 125, 125
# raster transform info: (515920.0, 80.0, 0, 7535040.0, 0, -80.0)
# write data to raster band
# set projection as: EPSG 32603
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/GeoTiffs/avgSpatialCoh.tif
# read data from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/temporalCoherence.h5
# initiate GDAL driver: GeoTIFF
# create raster band
# raster row / column number: 125, 125
# raster transform info: (515920.0, 80.0, 0, 7535040.0, 0, -80.0)
# write data to raster band
# set projection as: EPSG 32603
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/GeoTiffs/TemporalCoherence.tif

# %% [markdown]
# **Save the velocity geotiff**

# %%
velocity_name = "velocity"
vel_h5 = mint_path/f'{velocity_name}.h5'
vel_msk_h5 = mint_path/f'{velocity_name}_msk.h5'
vel_tiff = geotiff_path/f'{velocity_name}_msk.tif'
amp_tiff_tmp = geotiff_path/'season_amplitude_msk_tmp.tif'
amp_tiff = geotiff_path/'season_amplitude_msk.tif'

# !mask.py $vel_h5 -m $temp_coh_msk_h5
# !save_gdal.py $vel_msk_h5 --of GTIFF -o $vel_tiff
# !save_gdal.py $vel_msk_h5 -d annualAmplitude --of GTIFF -o $amp_tiff_tmp
# !gdal_calc.py -A $amp_tiff_tmp --outfile=$amp_tiff --calc="A*2" --NoDataValue=0
# !rm $amp_tiff_tmp
# Out:
# masking velocity        from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# masking annualAmplitude from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# masking annualPhase     from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# masking velocityStd     from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# masking intercept       from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# masking interceptStd    from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# masking residue         from /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity.h5 ...
# create HDF5 file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity_msk.h5 with w mode
# create dataset /velocity        of float32    in size of (125, 125)           with compression=None
# create dataset /annualAmplitude of float32    in size of (125, 125)           with compression=None
# create dataset /annualPhase     of float32    in size of (125, 125)           with compression=None
# create dataset /velocityStd     of float32    in size of (125, 125)           with compression=None
# create dataset /intercept       of float32    in size of (125, 125)           with compression=None
# create dataset /interceptStd    of float32    in size of (125, 125)           with compression=None
# create dataset /residue         of float32    in size of (125, 125)           with compression=None
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity_msk.h5
# read data from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity_msk.h5
# initiate GDAL driver: GeoTIFF
# create raster band
# raster row / column number: 125, 125
# raster transform info: (515920.0, 80.0, 0, 7535040.0, 0, -80.0)
# write data to raster band
# set projection as: EPSG 32603
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/GeoTiffs/velocity_msk.tif
# read annualAmplitude from file: /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/velocity_msk.h5
# initiate GDAL driver: GeoTIFF
# create raster band
# raster row / column number: 125, 125
# raster transform info: (515920.0, 80.0, 0, 7535040.0, 0, -80.0)
# write data to raster band
# set projection as: EPSG 32603
# finished writing to /home/jovyan/insar_sbas_permafrost_chen/MintPy_sbas/GeoTiffs/season_amplitude_msk_tmp.tif
# /home/jovyan/.local/envs/NISAR_EA_Workshop_2024_1/bin/gdal_calc.py:4: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   __import__('pkg_resources').run_script('GDAL==3.3.3', 'gdal_calc.py')
# 0.. 12.. 25.. 37.. 50.. 62.. 75.. 87.. 100 - Done

# %% [markdown]
# # Reference material

# %% [markdown]
# - Mintpy reference: *Yunjun, Z., H. Fattahi, F. Amelung (2019), Small baseline InSAR time series analysis: unwrapping error correction and noise reduction, preprint doi:[10.31223/osf.io/9sz6m](https://eartharxiv.org/9sz6m/).*
#
# - University of Miami online time-series viewer: https://insarmaps.miami.edu/
#
# - Mintpy Github repository: https://github.com/insarlab/MintPy

# %% [markdown]
# *MintPy_Time_Series_From_Prepared_Data_Stack.ipynb - Version 0.3.0 - January 2023*
#
# *Version Changes*
#
# - *store CDS credentials in `~/.cdsapirc` instead of in pyaps3 config*
# - *update pyaps3 config with CDS credentials in the notebook*
# - *add config option to use a local dask cluster for multithreading*
#     - *interferogram inversion*
#     - *dem error correction*
